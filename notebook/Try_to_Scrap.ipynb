# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install html5lib

# %%
import requests as req
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
respones = req.get('https://www.scrapethissite.com/pages/simple/')
print(respones.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(respones.content, 'html5lib')
print (soup.prettify())
if respones.status_code==200:
    div = soup.find(id='main-wrapper')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Countries of the World: A Simple Example | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="A single page that lists information about all the countries in the world. Good for those just get started with web scraping." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
blocks = soup.find_all("div", attrs="country")
result = []

for block in blocks:
  country_elements = block.find_all("h3")
  country = country_elements[0].text
  capital_elements = block.find_all("span", attrs="country-capital")
  capital = capital_elements[0].text
  population_elements = block.find_all("span", attrs="country-population")
  population = population_elements[0].text
  area_elements = block.find_all("span", attrs="country-area")
  area = area_elements[0].text

  result.append([country, capital, population,area])

# %%
df = pd.DataFrame(result, columns=['country', 'capital', 'population', 'country_area'])
df.sample()
# Out:
#                                               country    capital population  \
# 14  \n                            \n              ...  Mariehamn      26711
#
#    country_area
# 14       1580.0

# %%
df['country']= df['country'].str.replace('\n', ' ').str.strip()
df['capital'] = df['capital'].str.replace('\n', ' ').str.strip()
df['country_area']= df['country_area'].str.replace('\n', ' ').str.strip()
df['population'] = df['population'].str.replace('\n', ' ').str.strip()

# %%
df['population'] = (
    df['population']
    .astype(str)
    .str.replace(',', '', regex=False)
    .astype('int64')
)

df['country_area'] = (
    df['country_area']
    .astype(str)
    .str.replace(',', '', regex=False)
    .astype('float64')
)

# %%
df.to_csv('scrap_result.csv', index=False)
from google.colab import files
files.download('scrap_result.csv')
